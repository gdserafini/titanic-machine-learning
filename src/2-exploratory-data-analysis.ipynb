# %% [markdown]
# # EDA

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import warnings

# %% [markdown]
# ### Config

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Analysis

# %% [markdown]
# #### Data loading

# %%
df = pd.read_csv('../datasets/train_processed.csv')
print(df.shape)
df.head()
# Out:
# (714, 11)
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            1         0       3    male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
# 2            3         1       3  female  26.0      0      0   7.9250
# 3            4         1       1  female  35.0      1      0  53.1000
# 4            5         0       3    male  35.0      0      0   8.0500
#
#   Embarked SurvivedStr  FareLog2
# 0        S          No  2.857981
# 1        C         Yes  6.155492
# 2        S         Yes  2.986411
# 3        S         Yes  5.730640
# 4        S          No  3.008989

# %%
s_df = pd.read_csv('../datasets/survived_processed.csv')
print(s_df.shape)
s_df.head()
# Out:
# (290, 11)
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            2         1       1  female  38.0      1      0  71.2833
# 1            3         1       3  female  26.0      0      0   7.9250
# 2            4         1       1  female  35.0      1      0  53.1000
# 3            9         1       3  female  27.0      0      2  11.1333
# 4           10         1       2  female  14.0      1      0  30.0708
#
#   Embarked SurvivedStr  FareLog2
# 0        C         Yes  6.155492
# 1        S         Yes  2.986411
# 2        S         Yes  5.730640
# 3        S         Yes  3.476809
# 4        C         Yes  4.910291

# %%
ns_df = pd.read_csv('../datasets/not_survived_processed.csv')
print(ns_df.shape)
ns_df.head()
# Out:
# (424, 11)
#    PassengerId  Survived  Pclass   Sex   Age  SibSp  Parch     Fare Embarked  \
# 0            1         0       3  male  22.0      1      0   7.2500        S
# 1            5         0       3  male  35.0      0      0   8.0500        S
# 2            7         0       1  male  54.0      0      0  51.8625        S
# 3            8         0       3  male   2.0      3      1  21.0750        S
# 4           13         0       3  male  20.0      0      0   8.0500        S
#
#   SurvivedStr  FareLog2
# 0          No  2.857981
# 1          No  3.008989
# 2          No  5.696620
# 3          No  4.397461
# 4          No  3.008989
